# %%
import numpy as np
import pandas as pd
import json
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %%
# json.dumps() 是将 python 对象转化为 json
# json.loads() 是将 json 转化为 python 对象

dict_data = {"a": 1, "b": 2}
print(dict_data)
print(type(dict_data),dict_data)
# Out:
# {'a': 1, 'b': 2}
# <class 'dict'> {'a': 1, 'b': 2}

# %%
# 将dict格式数据转换成json格式字符串
dump_data = json.dumps(dict_data)
print(dump_data)
print(type(dump_data),dump_data)
# Out:
# {"a": 1, "b": 2}
# <class 'str'> {"a": 1, "b": 2}

# %%
# 将json格式字符串转换成对应的python值
load_data = json.loads(dump_data)
print(load_data)
print(type(load_data),load_data)
# Out:
# {'a': 1, 'b': 2}
# <class 'dict'> {'a': 1, 'b': 2}

# %%
import requests
import urllib.request
net163music = 'http://music.163.com/api/v1/resource/comments/R_SO_4_483671599?limit=10&offset=0'
headers = {'User-Agent':'chrome'}
response = requests.get(net163music, headers=headers,timeout=5)
response
# Out:
# <Response [200]>

# %%
musicdata = response.json()
musicdata
# Out:
# {'isMusician': False,
#  'userId': -1,
#  'topComments': [],
#  'moreHot': True,
#  'hotComments': [{'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 441846746,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': 1},
#     'vipType': 11,
#     'userType': 0,
#     'nickname': '哲也love',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/ubliTZpT_XEy5vzRiYFUKQ==/18797250790330390.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437807342,
#    'content': '八年过去了，郑爽还是如八年前的流星雨一样纯洁如外表，干净而亲切，就如这歌一样清新的声音仿佛把立夏的一切描述的淋漓尽致。',
#    'time': 1497320494166,
#    'likedCount': 414647,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 125834972,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '隔壁小俏',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/W7F-4W7tIDfy-ybYGO4czg==/19180980346939115.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437921816,
#    'content': '郑爽大概长了一张初恋的脸，无关所有，你看她叛逆，犯傻，糊涂，但还是相信她就是一个年轻又干净的女孩。谁能相信她已经出道八年了呢，还是那么干净的感觉。好喜欢陆之昂和立夏，不管书里怎么说，就算知道官配，就算知道最后不可能在一起，就是喜欢这一对。(不拉真人cp,只是陆之昂和立夏)',
#    'time': 1497330359251,
#    'likedCount': 324785,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 443832527,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '别多会少_不如莫遇',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/ZnY1LEJ8m5bbc27KfTn1FA==/19141397927998024.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437980751,
#    'content': '看过三遍原著，最让我爱的还是陆之昂，最让我心疼的还是遇见。看了剧，还是喜欢陆之昂，站司夏CP，但是却真的喜欢之昂和立夏。有的人说之昂对立夏只是朋友或者是兄妹。我却一直相信他是喜欢她的。是一场盛大的，无声无息的暗恋。',
#    'time': 1497334732521,
#    'likedCount': 240249,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 249421333,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '感谢你走过黑暗来到我身边',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/sArYYB9_dT-Q-CWP4U2zjw==/18648816720514807.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437806710,
#    'content': '我的世界里有我一个人就好，已经足够热闹。  ——郭敬明《夏至未至》',
#    'time': 1497321457271,
#    'likedCount': 225293,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 266416243,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '胡萝卜兔在路上5555',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/NfRlfS7YvwmFPJDBK1XQGA==/109951164183830990.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437802828,
#    'content': '昨天立夏的独白:太多时候，我们宁愿去制造一个假象，也不愿说出真正的原因。少年的心，就像雨后蜗牛的触角一样柔软，一喷就退缩，最后只留下坚硬的躯壳。傅小司，对不起，我们之间最好的方式就是保持距离。(表白立夏)',
#    'time': 1497321081175,
#    'likedCount': 121420,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 29892172,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': 1},
#     'vipType': 11,
#     'userType': 0,
#     'nickname': '春春君',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/SzS1_MwUT9Dft7fOfzcgbw==/109951163268443364.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437984759,
#    'content': '众人只知傅小司   无人识得岑宁儿。duo演唱会里给eason和声的那位沉静的 酷酷的姑娘   唱了一首the end of the world. 最后一句eason接上都忍不住哽咽。希望你爱这歌声  因为这剧  更因为这个唱着歌 闪闪发光的岑宁儿。',
#    'time': 1497335262930,
#    'likedCount': 107462,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 381991845,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': 'Asideserve',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/J5Futfn7mfTuaUt5H5qr0w==/18647717208894944.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437805992,
#    'content': '流年未亡，香樟依旧[爱心]八年了，那个曾经青涩的女孩被时光雕琢得越来越美好，一路艰辛，却又一路收获，终于被越来越多的人肯定[憨笑]没有心爱之物被他人发现的失落，心中只有满满的喜悦，因为我知道，她是那么努力，值得被这世界温柔相待，配得上所有美好[爱心]郑爽，加油[憨笑]',
#    'time': 1497322054445,
#    'likedCount': 71987,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 58777669,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': 'powerfulname',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/aO4zX-GchfGMLlMDbJwB-Q==/109951164055500474.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437821569,
#    'content': '这首歌曲讲述了立夏对傅小司（画家祭司）一直默默放在心底的崇拜之情，如同歌词中婉转而出的心声“我可以跟在你身后，像影子追着光梦游，我可以等在这路口，不管你会不会经过”，每一个女孩都是立夏，每一个立夏的生命里或许都有一位傅小司曾出现过。',
#    'time': 1497321993537,
#    'likedCount': 66051,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 279144730,
#     'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#      'musicPackage': None,
#      'redVipAnnualCount': -1},
#     'vipType': 11,
#     'userType': 0,
#     'nickname': '櫻鳩咲甜',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/kNzkFzq6NXUHXyy--mxzsA==/109951164600278748.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 439196609,
#    'content': '影由光而生 光却为影而在 记得中学时有个问题问着 什么时候的影子最长 是早晨太阳升起时 也是每天黄昏日落时 还有我望着你背影的时候',
#    'time': 1497437283419,
#    'likedCount': 58059,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 80256300,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '秋宇啊呀',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/qz_RB4-jG1TDUQDZjPhOOg==/109951164325055238.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 600126371,
#    'content': '昨天梦见你了 ，潜意识告诉我这是梦，后来我就努力没让梦醒。',
#    'time': 1509338932093,
#    'likedCount': 57815,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 262199170,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '哟西哟西丶',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/CepcYQ-fqkuPz_2zB5U-Gw==/109951164401889644.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 578577882,
#    'content': '25岁做电商亏损，觉得给不了她好的生活放弃了最想照顾一生的人，秦晓娜我会跟在你身后，做你的追光者。',
#    'time': 1507350537992,
#    'likedCount': 44049,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 1306951092,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '北辰ayy',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/wbxqngiBcgvbgGLb8PMztg==/109951163146755623.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 649072904,
#    'content': '叮当陪了大雄80年在大雄临死前他对叮说:“我走之后你就回到属于你的地方吧！”叮当同意了！大雄死后…叮当用时光机回到了80年前，对小时候的大雄说:“大雄你好，我叫叮当。” 每次看到这个段子都好感动，----人生若只如初见朋友也好，爱人也罢，如果累了，我们就回到第一天见面的时候。',
#    'time': 1513984880016,
#    'likedCount': 43872,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 487428069,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '_你是年少的欢喜呀_',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/nHIjkJXXRse2_OB7hRxeEQ==/109951163328232188.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437860316,
#    'content': '嗨，亲爱的郑爽啊，无论时间长短，岁月流转，你还是那个你，那个纯粹的你，等你带给我们一个又一个角色，而我们依然在背后爱你。',
#    'time': 1497325304077,
#    'likedCount': 42481,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 117737425,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '你咋不上天-----呢',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/s_R-eGSsD6j0c-aIuv1K_g==/19166686695662329.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 570211183,
#    'content': '你是耀眼的星河，耀眼的让人想哭，于是我成了追光者，可惜梦游的时间再长，也不过一晚上，天亮了，你就让我醒了。你还笑我落魄得像个熊样，你知道吗，讽刺地是，还真有一首歌叫《失恋熊样》，你每次都是这样，即使我已经失望，依旧能恰到好处地在我伤口上再添一刀。',
#    'time': 1506666877392,
#    'likedCount': 31929,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 249421333,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '感谢你走过黑暗来到我身边',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/sArYYB9_dT-Q-CWP4U2zjw==/18648816720514807.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 437814074,
#    'content': '我再也不会这样地去想念你们了。我再也不会这样地去为你们的命运担心了。因为我知道，你们成熟了，那些用惨痛的失败学会的事情，让你们变得那么好。好得让我可以看着你们安静地笑了，好得让喜欢得胸腔深处发出一阵又一阵酸楚。这就是为什么，我在最后会一个人留下来站在空无一人的大地上，难过地哭泣。',
#    'time': 1497320569040,
#    'likedCount': 28212,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': None,
#    'repliedMark': None,
#    'liked': False}],
#  'code': 200,
#  'comments': [{'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 1742365093,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': 'SHANGHA11',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/RLeBJe4D1ZzUtltxfoKDMg==/109951163250239066.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221665586,
#    'content': '加油!',
#    'time': 1585029831634,
#    'likedCount': 0,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 3219891459,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '是桃妹鸭',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/fkwC7zowwpUGNJk1S3jfPw==/109951164712983660.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221645241,
#    'content': '三年了啊',
#    'time': 1585028115637,
#    'likedCount': 0,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 1850782531,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '别揪诺诺耳朵',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/aRs6pdVC29DWzB4d0w7Z6g==/109951164739059060.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221621319,
#    'content': '爽爽也举办了十年粉丝会 ~这么快',
#    'time': 1585027413141,
#    'likedCount': 0,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 1778866502,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '蒹葭有梦',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/zRnaGB6XWVhxNw7gSNgvxg==/109951164769580398.jpg'},
#    'beReplied': [{'user': {'locationInfo': None,
#       'liveInfo': None,
#       'userId': 441846746,
#       'vipRights': None,
#       'vipType': 11,
#       'userType': 0,
#       'nickname': '哲也love',
#       'remarkName': None,
#       'expertTags': None,
#       'authStatus': 0,
#       'experts': None,
#       'avatarUrl': 'http://p1.music.126.net/ubliTZpT_XEy5vzRiYFUKQ==/18797250790330390.jpg'},
#      'beRepliedCommentId': 437807342,
#      'content': '八年过去了，郑爽还是如八年前的流星雨一样纯洁如外表，干净而亲切，就如这歌一样清新的声音仿佛把立夏的一切描述的淋漓尽致。',
#      'status': 0,
#      'expressionUrl': None}],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221561776,
#    'content': 'olo',
#    'time': 1585026651828,
#    'likedCount': 0,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 437807342,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 1427330404,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '-漱石',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/8R2YM-MqCSTn3JdLKSyhyw==/109951164403888130.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221603316,
#    'content': '郑爽真的干净又温柔',
#    'time': 1585026358717,
#    'likedCount': 1,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 2085280078,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '邵晨曦_ouGG',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/RLeBJe4D1ZzUtltxfoKDMg==/109951163250239066.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221587500,
#    'content': '这是我们学校起床铃，在家待久了，回味一下[大笑]',
#    'time': 1585026346235,
#    'likedCount': 1,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 423059148,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '子佩233',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/urf1vypflRJ2h1ScCYXBzw==/19211766672501667.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221547708,
#    'content': '表白郑爽',
#    'time': 1585025620403,
#    'likedCount': 1,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 2092784256,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '抱紧柔情_',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/cmt_oMXbSdqWS4UhLDGM1Q==/109951164814000047.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221577217,
#    'content': '唉呀，一不小心就2020年了还有人在听这首歌吗？',
#    'time': 1585025277463,
#    'likedCount': 4,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 3260252569,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '里知恩lulululululululu',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/t1ODsdJ4m1TYascGX4iw9Q==/109951164833664563.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221603921,
#    'content': '想给陆之昂最好的结局',
#    'time': 1585025173851,
#    'likedCount': 1,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False},
#   {'user': {'locationInfo': None,
#     'liveInfo': None,
#     'userId': 646680224,
#     'vipRights': None,
#     'vipType': 0,
#     'userType': 0,
#     'nickname': '呵呵哈哈帅',
#     'remarkName': None,
#     'expertTags': None,
#     'authStatus': 0,
#     'experts': None,
#     'avatarUrl': 'http://p1.music.126.net/K0s5sIzb4-uZkrH8OA--Nw==/109951164744694735.jpg'},
#    'beReplied': [],
#    'pendantData': None,
#    'showFloorComment': None,
#    'status': 0,
#    'commentId': 3221587118,
#    'content': '好听，却不禁想哭，听了这么多遍，还是原来的样子，也只有你还藏在我的心里了',
#    'time': 1585025128352,
#    'likedCount': 1,
#    'expressionUrl': None,
#    'commentLocationType': 0,
#    'parentCommentId': 0,
#    'decoration': {},
#    'repliedMark': None,
#    'liked': False}],
#  'total': 283075,
#  'more': True}

# %%
musicdata['hotComments'][7]['content']
# Out:
# '这首歌曲讲述了立夏对傅小司（画家祭司）一直默默放在心底的崇拜之情，如同歌词中婉转而出的心声“我可以跟在你身后，像影子追着光梦游，我可以等在这路口，不管你会不会经过”，每一个女孩都是立夏，每一个立夏的生命里或许都有一位傅小司曾出现过。'

# %%
musicdata['hotComments'][7]['likedCount']
# Out:
# 66051

# %%
musicdatafliter = []
musicdatahot = musicdata['hotComments']
musicdatahot
# Out:
# [{'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 441846746,
#    'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#     'musicPackage': None,
#     'redVipAnnualCount': 1},
#    'vipType': 11,
#    'userType': 0,
#    'nickname': '哲也love',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/ubliTZpT_XEy5vzRiYFUKQ==/18797250790330390.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437807342,
#   'content': '八年过去了，郑爽还是如八年前的流星雨一样纯洁如外表，干净而亲切，就如这歌一样清新的声音仿佛把立夏的一切描述的淋漓尽致。',
#   'time': 1497320494166,
#   'likedCount': 414647,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 125834972,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '隔壁小俏',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/W7F-4W7tIDfy-ybYGO4czg==/19180980346939115.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437921816,
#   'content': '郑爽大概长了一张初恋的脸，无关所有，你看她叛逆，犯傻，糊涂，但还是相信她就是一个年轻又干净的女孩。谁能相信她已经出道八年了呢，还是那么干净的感觉。好喜欢陆之昂和立夏，不管书里怎么说，就算知道官配，就算知道最后不可能在一起，就是喜欢这一对。(不拉真人cp,只是陆之昂和立夏)',
#   'time': 1497330359251,
#   'likedCount': 324785,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 443832527,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '别多会少_不如莫遇',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/ZnY1LEJ8m5bbc27KfTn1FA==/19141397927998024.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437980751,
#   'content': '看过三遍原著，最让我爱的还是陆之昂，最让我心疼的还是遇见。看了剧，还是喜欢陆之昂，站司夏CP，但是却真的喜欢之昂和立夏。有的人说之昂对立夏只是朋友或者是兄妹。我却一直相信他是喜欢她的。是一场盛大的，无声无息的暗恋。',
#   'time': 1497334732521,
#   'likedCount': 240249,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 249421333,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '感谢你走过黑暗来到我身边',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/sArYYB9_dT-Q-CWP4U2zjw==/18648816720514807.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437806710,
#   'content': '我的世界里有我一个人就好，已经足够热闹。  ——郭敬明《夏至未至》',
#   'time': 1497321457271,
#   'likedCount': 225293,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 266416243,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '胡萝卜兔在路上5555',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/NfRlfS7YvwmFPJDBK1XQGA==/109951164183830990.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437802828,
#   'content': '昨天立夏的独白:太多时候，我们宁愿去制造一个假象，也不愿说出真正的原因。少年的心，就像雨后蜗牛的触角一样柔软，一喷就退缩，最后只留下坚硬的躯壳。傅小司，对不起，我们之间最好的方式就是保持距离。(表白立夏)',
#   'time': 1497321081175,
#   'likedCount': 121420,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 29892172,
#    'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#     'musicPackage': None,
#     'redVipAnnualCount': 1},
#    'vipType': 11,
#    'userType': 0,
#    'nickname': '春春君',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/SzS1_MwUT9Dft7fOfzcgbw==/109951163268443364.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437984759,
#   'content': '众人只知傅小司   无人识得岑宁儿。duo演唱会里给eason和声的那位沉静的 酷酷的姑娘   唱了一首the end of the world. 最后一句eason接上都忍不住哽咽。希望你爱这歌声  因为这剧  更因为这个唱着歌 闪闪发光的岑宁儿。',
#   'time': 1497335262930,
#   'likedCount': 107462,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 381991845,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': 'Asideserve',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/J5Futfn7mfTuaUt5H5qr0w==/18647717208894944.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437805992,
#   'content': '流年未亡，香樟依旧[爱心]八年了，那个曾经青涩的女孩被时光雕琢得越来越美好，一路艰辛，却又一路收获，终于被越来越多的人肯定[憨笑]没有心爱之物被他人发现的失落，心中只有满满的喜悦，因为我知道，她是那么努力，值得被这世界温柔相待，配得上所有美好[爱心]郑爽，加油[憨笑]',
#   'time': 1497322054445,
#   'likedCount': 71987,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 58777669,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': 'powerfulname',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/aO4zX-GchfGMLlMDbJwB-Q==/109951164055500474.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437821569,
#   'content': '这首歌曲讲述了立夏对傅小司（画家祭司）一直默默放在心底的崇拜之情，如同歌词中婉转而出的心声“我可以跟在你身后，像影子追着光梦游，我可以等在这路口，不管你会不会经过”，每一个女孩都是立夏，每一个立夏的生命里或许都有一位傅小司曾出现过。',
#   'time': 1497321993537,
#   'likedCount': 66051,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 279144730,
#    'vipRights': {'associator': {'vipCode': 100, 'rights': True},
#     'musicPackage': None,
#     'redVipAnnualCount': -1},
#    'vipType': 11,
#    'userType': 0,
#    'nickname': '櫻鳩咲甜',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/kNzkFzq6NXUHXyy--mxzsA==/109951164600278748.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 439196609,
#   'content': '影由光而生 光却为影而在 记得中学时有个问题问着 什么时候的影子最长 是早晨太阳升起时 也是每天黄昏日落时 还有我望着你背影的时候',
#   'time': 1497437283419,
#   'likedCount': 58059,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 80256300,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '秋宇啊呀',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/qz_RB4-jG1TDUQDZjPhOOg==/109951164325055238.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 600126371,
#   'content': '昨天梦见你了 ，潜意识告诉我这是梦，后来我就努力没让梦醒。',
#   'time': 1509338932093,
#   'likedCount': 57815,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 262199170,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '哟西哟西丶',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/CepcYQ-fqkuPz_2zB5U-Gw==/109951164401889644.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 578577882,
#   'content': '25岁做电商亏损，觉得给不了她好的生活放弃了最想照顾一生的人，秦晓娜我会跟在你身后，做你的追光者。',
#   'time': 1507350537992,
#   'likedCount': 44049,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 1306951092,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '北辰ayy',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/wbxqngiBcgvbgGLb8PMztg==/109951163146755623.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 649072904,
#   'content': '叮当陪了大雄80年在大雄临死前他对叮说:“我走之后你就回到属于你的地方吧！”叮当同意了！大雄死后…叮当用时光机回到了80年前，对小时候的大雄说:“大雄你好，我叫叮当。” 每次看到这个段子都好感动，----人生若只如初见朋友也好，爱人也罢，如果累了，我们就回到第一天见面的时候。',
#   'time': 1513984880016,
#   'likedCount': 43872,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 487428069,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '_你是年少的欢喜呀_',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/nHIjkJXXRse2_OB7hRxeEQ==/109951163328232188.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437860316,
#   'content': '嗨，亲爱的郑爽啊，无论时间长短，岁月流转，你还是那个你，那个纯粹的你，等你带给我们一个又一个角色，而我们依然在背后爱你。',
#   'time': 1497325304077,
#   'likedCount': 42481,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 117737425,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '你咋不上天-----呢',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/s_R-eGSsD6j0c-aIuv1K_g==/19166686695662329.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 570211183,
#   'content': '你是耀眼的星河，耀眼的让人想哭，于是我成了追光者，可惜梦游的时间再长，也不过一晚上，天亮了，你就让我醒了。你还笑我落魄得像个熊样，你知道吗，讽刺地是，还真有一首歌叫《失恋熊样》，你每次都是这样，即使我已经失望，依旧能恰到好处地在我伤口上再添一刀。',
#   'time': 1506666877392,
#   'likedCount': 31929,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False},
#  {'user': {'locationInfo': None,
#    'liveInfo': None,
#    'userId': 249421333,
#    'vipRights': None,
#    'vipType': 0,
#    'userType': 0,
#    'nickname': '感谢你走过黑暗来到我身边',
#    'remarkName': None,
#    'expertTags': None,
#    'authStatus': 0,
#    'experts': None,
#    'avatarUrl': 'http://p1.music.126.net/sArYYB9_dT-Q-CWP4U2zjw==/18648816720514807.jpg'},
#   'beReplied': [],
#   'pendantData': None,
#   'showFloorComment': None,
#   'status': 0,
#   'commentId': 437814074,
#   'content': '我再也不会这样地去想念你们了。我再也不会这样地去为你们的命运担心了。因为我知道，你们成熟了，那些用惨痛的失败学会的事情，让你们变得那么好。好得让我可以看着你们安静地笑了，好得让喜欢得胸腔深处发出一阵又一阵酸楚。这就是为什么，我在最后会一个人留下来站在空无一人的大地上，难过地哭泣。',
#   'time': 1497320569040,
#   'likedCount': 28212,
#   'expressionUrl': None,
#   'commentLocationType': 0,
#   'parentCommentId': 0,
#   'decoration': None,
#   'repliedMark': None,
#   'liked': False}]

# %%
import jsonpath
for job in musicdatahot:
    dic={}
    dic['content']=jsonpath.jsonpath(job,'$..content')[0] #评论
    dic['userId']=jsonpath.jsonpath(job['user'],'$..userId')[0]  #用户ID
    dic['nickname']=jsonpath.jsonpath(job['user'],'$..nickname')[0]#用户名
    dic['likedCount']=jsonpath.jsonpath(job,'$..likedCount')[0] #赞数
    musicdatafliter.append(dic)
musicdatafliter = pd.DataFrame(musicdatafliter)
musicdatafliter
# Out:
#                                               content      userId  \
# 0   八年过去了，郑爽还是如八年前的流星雨一样纯洁如外表，干净而亲切，就如这歌一样清新的声音仿佛把...   441846746
# 1   郑爽大概长了一张初恋的脸，无关所有，你看她叛逆，犯傻，糊涂，但还是相信她就是一个年轻又干净的...   125834972
# 2   看过三遍原著，最让我爱的还是陆之昂，最让我心疼的还是遇见。看了剧，还是喜欢陆之昂，站司夏CP...   443832527
# 3                   我的世界里有我一个人就好，已经足够热闹。  ——郭敬明《夏至未至》   249421333
# 4   昨天立夏的独白:太多时候，我们宁愿去制造一个假象，也不愿说出真正的原因。少年的心，就像雨后蜗...   266416243
# ..                                                ...         ...
# 25  25岁做电商亏损，觉得给不了她好的生活放弃了最想照顾一生的人，秦晓娜我会跟在你身后，做你的追光者。   262199170
# 26  叮当陪了大雄80年在大雄临死前他对叮说:“我走之后你就回到属于你的地方吧！”叮当同意了！大雄...  1306951092
# 27  嗨，亲爱的郑爽啊，无论时间长短，岁月流转，你还是那个你，那个纯粹的你，等你带给我们一个又一个...   487428069
# 28  你是耀眼的星河，耀眼的让人想哭，于是我成了追光者，可惜梦游的时间再长，也不过一晚上，天亮了，...   117737425
# 29  我再也不会这样地去想念你们了。我再也不会这样地去为你们的命运担心了。因为我知道，你们成熟了，...   249421333
#
#         nickname  likedCount
# 0         哲也love      414647
# 1           隔壁小俏      324785
# 2      别多会少_不如莫遇      240249
# 3   感谢你走过黑暗来到我身边      225293
# 4    胡萝卜兔在路上5555      121420
# ..           ...         ...
# 25         哟西哟西丶       44049
# 26         北辰ayy       43872
# 27    _你是年少的欢喜呀_       42481
# 28   你咋不上天-----呢       31929
# 29  感谢你走过黑暗来到我身边       28212
#
# [30 rows x 4 columns]
